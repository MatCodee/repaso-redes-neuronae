# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler,OneHotEncoder
from sklearn.compose import ColumnTransformer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow import keras
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
data = pd.read_csv('Churn_Modelling.csv')

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
X = data.iloc[:,3:13].values
y = data.iloc[:,13].values

# %%
X
# Out:
# array([[619, 'France', 'Female', ..., 1, 1, 101348.88],
#        [608, 'Spain', 'Female', ..., 0, 1, 112542.58],
#        [502, 'France', 'Female', ..., 1, 0, 113931.57],
#        ...,
#        [709, 'France', 'Female', ..., 0, 1, 42085.58],
#        [772, 'Germany', 'Male', ..., 1, 0, 92888.52],
#        [792, 'France', 'Female', ..., 1, 0, 38190.78]], dtype=object)

# %%
# variables categoricas del pais
lb1 = LabelEncoder()
X[:,1] = lb1.fit_transform(X[:,1])

# %%
# tipo de variables de sexo de la persona
lb2 = LabelEncoder()
X[:,2] = lb2.fit_transform(X[:,2])

# %%
X
# Out:
# array([[619, 0, 0, ..., 1, 1, 101348.88],
#        [608, 2, 0, ..., 0, 1, 112542.58],
#        [502, 0, 0, ..., 1, 0, 113931.57],
#        ...,
#        [709, 0, 0, ..., 0, 1, 42085.58],
#        [772, 1, 1, ..., 1, 0, 92888.52],
#        [792, 0, 0, ..., 1, 0, 38190.78]], dtype=object)

# %%
transformer = ColumnTransformer(
    transformers=[
        ("Churn_Modelling",        # Un nombre de la transformación
         OneHotEncoder(categories='auto'), # La clase a la que transformar
         [1]            # Las columnas a transformar.
         )
    ], remainder='passthrough'
)
X = transformer.fit_transform(X)
X = X[:,1:]

# %%
X.shape
# Out:
# (10000, 11)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %% [markdown]
# ### inicializacion de la red neuronal artificial

# %%
# especificacion de la arquietctura:
# inicializacion de la red neuronal artificial
rna = Sequential()

# %%
# añadir capa de red neuronal
rna.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=11))

# %%
# Añadir una segunda capa
rna.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
rna.add(Dense(units=3,kernel_initializer='uniform',activation='relu'))

# %%
# Añadir la capa de salida:
rna.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))

# %%
# Compilar la red neuronal artificial:
rna.compile(optimizer='adam',loss='binary_crossentropy',metrics=["accuracy"])

# %%
# Ajustamos el modelo para entrenamiento
rna.fit(X_train,y_train,batch_size=10,epochs=50)
# Out:
# Train on 7500 samples
# Epoch 1/50
# 7500/7500 [==============================] - 1s 145us/sample - loss: 0.4862 - accuracy: 0.7963
# Epoch 2/50
# 7500/7500 [==============================] - 1s 90us/sample - loss: 0.4292 - accuracy: 0.7963
# Epoch 3/50
# 7500/7500 [==============================] - 1s 90us/sample - loss: 0.4222 - accuracy: 0.8021s - loss: 0.4231 - accuracy: 0.80
# Epoch 4/50
# 7500/7500 [==============================] - 1s 91us/sample - loss: 0.4178 - accuracy: 0.8221
# Epoch 5/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4156 - accuracy: 0.8284
# Epoch 6/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4134 - accuracy: 0.8309
# Epoch 7/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4119 - accuracy: 0.8317
# Epoch 8/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4108 - accuracy: 0.8323
# Epoch 9/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4097 - accuracy: 0.8319
# Epoch 10/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4082 - accuracy: 0.8313
# Epoch 11/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4077 - accuracy: 0.8343
# Epoch 12/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4074 - accuracy: 0.8327
# Epoch 13/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4070 - accuracy: 0.8337
# Epoch 14/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4061 - accuracy: 0.8347
# Epoch 15/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4060 - accuracy: 0.8323
# Epoch 16/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4052 - accuracy: 0.8337
# Epoch 17/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4048 - accuracy: 0.8344
# Epoch 18/50
# 7500/7500 [==============================] - 1s 97us/sample - loss: 0.4050 - accuracy: 0.8332
# Epoch 19/50
# 7500/7500 [==============================] - 1s 97us/sample - loss: 0.4049 - accuracy: 0.8347
# Epoch 20/50
# 7500/7500 [==============================] - 1s 98us/sample - loss: 0.4040 - accuracy: 0.8337
# Epoch 21/50
# 7500/7500 [==============================] - 1s 93us/sample - loss: 0.4040 - accuracy: 0.8360s - loss: 0.3865 - accu - ETA: 0s - loss: 0.4053 - accuracy: 0.
# Epoch 22/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4038 - accuracy: 0.8341
# Epoch 23/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4028 - accuracy: 0.8344
# Epoch 24/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4041 - accuracy: 0.8319
# Epoch 25/50
# 7500/7500 [==============================] - 1s 95us/sample - loss: 0.4029 - accuracy: 0.8341
# Epoch 26/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4031 - accuracy: 0.8339
# Epoch 27/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4028 - accuracy: 0.8359
# Epoch 28/50
# 7500/7500 [==============================] - 1s 93us/sample - loss: 0.4025 - accuracy: 0.8348
# Epoch 29/50
# 7500/7500 [==============================] - 1s 98us/sample - loss: 0.4030 - accuracy: 0.8340
# Epoch 30/50
# 7500/7500 [==============================] - 1s 98us/sample - loss: 0.4019 - accuracy: 0.8341
# Epoch 31/50
# 7500/7500 [==============================] - 1s 95us/sample - loss: 0.4026 - accuracy: 0.8344
# Epoch 32/50
# 7500/7500 [==============================] - 1s 94us/sample - loss: 0.4022 - accuracy: 0.8344s - loss: 0.4020 - accuracy: 0. - ETA: 0s - loss: 0.3992 - accura
# Epoch 33/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4022 - accuracy: 0.8327
# Epoch 34/50
# 7500/7500 [==============================] - 1s 93us/sample - loss: 0.4022 - accuracy: 0.8351
# Epoch 35/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4020 - accuracy: 0.8339
# Epoch 36/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4015 - accuracy: 0.8345
# Epoch 37/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4021 - accuracy: 0.8345
# Epoch 38/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4018 - accuracy: 0.8347
# Epoch 39/50
# 7500/7500 [==============================] - 1s 93us/sample - loss: 0.4021 - accuracy: 0.8356
# Epoch 40/50
# 7500/7500 [==============================] - 1s 92us/sample - loss: 0.4015 - accuracy: 0.8339
# Epoch 41/50
# 7500/7500 [==============================] - 1s 93us/sample - loss: 0.4010 - accuracy: 0.8352
# Epoch 42/50
# 7500/7500 [==============================] - 1s 93us/sample - loss: 0.4018 - accuracy: 0.8335
# Epoch 43/50
# 7500/7500 [==============================] - 1s 96us/sample - loss: 0.4009 - accuracy: 0.8336s - loss: 0.4013 - accuracy: 0.
# Epoch 44/50
# 7500/7500 [==============================] - 1s 99us/sample - loss: 0.4017 - accuracy: 0.8351s - loss: 0.3929 - accuracy:  - ETA: 0s - loss: 0.3935 - accu
# Epoch 45/50
# 7500/7500 [==============================] - 1s 95us/sample - loss: 0.4016 - accuracy: 0.8353s - loss: 0.4015 - accuracy: 0.83
# Epoch 46/50
# 7500/7500 [==============================] - 1s 102us/sample - loss: 0.4012 - accuracy: 0.8332
# Epoch 47/50
# 7500/7500 [==============================] - 1s 97us/sample - loss: 0.4014 - accuracy: 0.8352s - loss: 0.3996 - accuracy
# Epoch 48/50
# 7500/7500 [==============================] - 1s 94us/sample - loss: 0.4015 - accuracy: 0.8360
# Epoch 49/50
# 7500/7500 [==============================] - 1s 94us/sample - loss: 0.4015 - accuracy: 0.8371
# Epoch 50/50
# 7500/7500 [==============================] - 1s 93us/sample - loss: 0.4008 - accuracy: 0.8341

# %%
predict = rna.predict(X_test)

# %%
predict = (predict>0.5)

# %%
y_test
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
accuracy_score(y_test,predict)
# Out:
# 0.8432

# %%
confusion_matrix(y_test,predict)
# Out:
# array([[1930,   61],
#        [ 331,  178]])

# %% [markdown]
# ## Mejorar el modelo de red neuronal artificial
# * Usando nuestro modelo que logro una precision de 0.864 como podemos mejorar el modelo? una forma de mejorar el modelo es potenciar lo que es la precision del modeoo y disminuir la variabilidad de este , podemos usar la tecnica llamada cross-validation en donde logramos una distribucion de los datos

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score,GridSearchCV

# %%
def build_classifier():
    rna = Sequential()
    rna.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=11))
    rna.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
    rna.add(Dense(units=3,kernel_initializer='uniform',activation='relu'))
    rna.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
    rna.compile(optimizer='adam',loss='binary_crossentropy',metrics=["accuracy"])
    
    return rna

# %%
classifier = KerasClassifier(build_fn=build_classifier,batch_size=10,nb_epoch=100)
accuracies = cross_val_score(estimator=classifier,X = X_train,y = y_train)
# Out:
# Train on 6000 samples
# 6000/6000 [==============================] - 1s 153us/sample - loss: 0.5123 - accuracy: 0.7985
# 1500/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# Train on 6000 samples
# 6000/6000 [==============================] - 1s 161us/sample - loss: 0.5212 - accuracy: 0.7957
# 1500/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# Train on 6000 samples
# 6000/6000 [==============================] - 1s 165us/sample - loss: 0.5215 - accuracy: 0.7915
# 1500/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# Train on 6000 samples
# 6000/6000 [==============================] - 1s 158us/sample - loss: 0.6277 - accuracy: 0.7968
# 1500/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# Train on 6000 samples
# 6000/6000 [==============================] - 1s 165us/sample - loss: 0.5059 - accuracy: 0.7960
# 1500/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %%
accuracies
# Out:
# array([0.78733331, 0.79533333, 0.81266665, 0.78933334, 0.79666668])

# %%
mean = accuracies.mean()
mean
# Out:
# 0.7962666630744935

# %%
variance = accuracies.std()
variance
# Out:
# 0.008920387643462467

# %% [markdown]
# ## Mejorar la RNA
# * Regularizacion del Dropout para evitar le overfitting

# %%
classifier = KerasClassifier(build_fn=build_classifier)

# %%
parameters = {
    'batch_size': [25,32],
    'nb_epoch'  : [100,500],
    'optimizer' : ['adam','rmsprop'],
}

# %%
grid_search = GridSearchCV(estimator=classifier,param_grid=parameters,scoring='accuracy',cv=10)
grid_search = grid_search.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/sk/n1lcwz4s6g5by_ywwd6ts2gh0000gn/T/ipykernel_4927/1870826060.py in <module>
#       1 grid_search = GridSearchCV(estimator=classifier,param_grid=parameters,scoring='accuracy',cv=10)
# ----> 2 grid_search = grid_search.fit(X_train,y_train)
#
# ~/opt/anaconda3/envs/tf/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# ~/opt/anaconda3/envs/tf/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# -> 1392         evaluate_candidates(ParameterGrid(self.param_grid))
#    1393
#    1394
#
# ~/opt/anaconda3/envs/tf/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     849                     )
#     850                     for (cand_idx, parameters), (split_idx, (train, test)) in product(
# --> 851                         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     852                     )
#     853                 )
#
# ~/opt/anaconda3/envs/tf/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1041             # remaining jobs.
#    1042             self._iterating = False
# -> 1043             if self.dispatch_one_batch(iterator):
#    1044                 self._iterating = self._original_iterator is not None
#    1045
#
# ~/opt/anaconda3/envs/tf/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# ~/opt/anaconda3/envs/tf/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/envs/tf/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/opt/anaconda3/envs/tf/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/opt/anaconda3/envs/tf/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# ~/opt/anaconda3/envs/tf/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# ~/opt/anaconda3/envs/tf/lib/python3.7/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# ~/opt/anaconda3/envs/tf/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     666             cloned_parameters[k] = clone(v, safe=False)
#     667
# --> 668         estimator = estimator.set_params(**cloned_parameters)
#     669
#     670     start_time = time.time()
#
# ~/opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/wrappers/scikit_learn.py in set_params(self, **params)
#     128         self
#     129     """
# --> 130     self.check_params(params)
#     131     self.sk_params.update(params)
#     132     return self
#
# ~/opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow_core/python/keras/wrappers/scikit_learn.py in check_params(self, params)
#     104       else:
#     105         if params_name != 'nb_epoch':
# --> 106           raise ValueError('{} is not a legal parameter'.format(params_name))
#     107
#     108   def get_params(self, **params):  # pylint: disable=unused-argument
#
# ValueError: optimizer is not a legal parameter

# %%
#best_parameters = grid_search.best_params_
#best_accuracy = grid_search.best_score_
